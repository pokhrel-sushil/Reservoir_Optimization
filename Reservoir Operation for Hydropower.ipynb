# %%
import pandas as pd
import numpy as np
import math

# %%
def multiplication_factor(p_unit, t_unit):
    if p_unit=='KW' and t_unit=='Daily':
        factor = 2725/(24)
    elif p_unit=='KW' and t_unit=='Weekly':
        factor = 2725/(7*24)   
    elif p_unit=='KW' and t_unit=='Monthly':
        factor = 2725/(30*24)
    elif p_unit=='KW' and t_unit=='Yearly':
        factor = 2725/(365*24)
    elif p_unit=='MW' and t_unit=='Daily':
        factor = 2725/(1000*24)
    elif p_unit=='MW' and t_unit=='Weekly':
        factor = 2725/(1000*7*24)   
    elif p_unit=='MW' and t_unit=='Monthly':
        factor = 2725/(1000*30*24)
    else:
        factor = 2725/(1000*365*24)
    
    return factor

# formula for release
def release(P,RL, TWL, eff, power_unit, time_unit):
    mult_factor = multiplication_factor(power_unit,time_unit)
    return P/(mult_factor*(RL - TWL )* eff)

# %%
reservoir_capacity = 7000
minm_power = 75 # in MW
TWL = 97 # m
efficiency = 0.8

# %%
def interpolator(value,df):
    
#     df = df.sort('Capacity').reset_index(drop=True)
    
   # Boundary cases
    if value <= df.at[0, 'Capacity']:
        return df.at[0, 'Elevation'], df.at[0, 'Area']
    
    if value >= df.at[df.index[-1], 'Capacity']:
        return df.at[df.index[-1], 'Elevation'], df.at[df.index[-1], 'Area']
    
    # Find upper bound index
    upper_idx = None
    for idx in df.index:
        if df.at[idx, 'Capacity'] >= value:
            upper_idx = idx
            break
    
    # upper_idx is guaranteed to exist and be >= 1
    lower_idx = upper_idx - 1
    
    x_low, x_high = df.at[lower_idx, 'Capacity'], df.at[upper_idx, 'Capacity']
    elev_low, elev_high = df.at[lower_idx, 'Elevation'], df.at[upper_idx, 'Elevation']
    area_low, area_high = df.at[lower_idx, 'Area'], df.at[upper_idx, 'Area']
    
    elevation = elev_low + (elev_high - elev_low)/(x_high - x_low) * (value - x_low)
    area = area_low + (area_high - area_low)/(x_high - x_low) * (value - x_low)
    
    return elevation, area

# %%
# Reading data from excel sheets
res_df = pd.read_excel("Elevation Storage Area Relationship for reservoir.xlsx", sheet_name='Sheet1', header=0)
inflow_df = pd.read_excel("Inflow and Evapotranspiration data.xlsx", sheet_name='Reservoir_Inflow', header=2)
et_df = pd.read_excel("Inflow and Evapotranspiration data.xlsx", sheet_name='ET', header=2)

# %%
# df = inflow_df.iloc[:, 1:20].apply(pd.to_numeric, errors='coerce')

# %%
inflow_df['Mean']=inflow_df.iloc[:,1:20].mean(axis=1)
inflow_df
# Out:
#      Days  1981  1982   1983  1984   1985   1986  1987  1988  1989  ...  1992  \
# 0       1  73.0  80.5   85.0  92.5   87.7  102.0  95.6  80.6  60.0  ...  80.6
# 1       2  71.5  79.0   78.7  91.0   88.8   99.3  95.6  79.3  60.0  ...  80.6
# 2       3  70.0  77.5   76.6  91.0   81.1   98.1  94.2  79.3  62.0  ...  79.3
# 3       4  71.5  79.0   74.5  89.5   80.1   95.6  92.7  79.3  59.0  ...  79.3
# 4       5  71.5  98.0   74.5  89.5   83.2   93.4  92.7  77.9  56.0  ...  79.3
# ..    ...   ...   ...    ...   ...    ...    ...   ...   ...   ...  ...   ...
# 361   362  85.2  71.4  110.0  75.9  202.0  101.0  81.9  74.0  92.8  ...  70.7
# 362   363  83.6  73.5  106.0  74.8  138.0  100.0  81.9  70.0  90.2  ...  70.7
# 363   364  85.2  90.7  100.0  74.8  118.0   98.5  81.9  66.0  88.9  ...  70.7
# 364   365  80.5  96.4   95.5  73.8  109.0   97.1  81.9  63.0  88.9  ...  69.5
# 365   366  82.0  92.6   92.5  73.8  104.0   97.1  80.6  62.0  87.6  ...  70.7
#
#      1993  1994  1995  1996   1997  1998  1999  2000       Mean
# 0    70.7  75.2  64.9  77.5   74.0  99.5  79.0  75.9  82.400000
# 1    70.7  75.2  67.0  77.5   72.8  98.0  78.7  75.9  81.494737
# 2    71.1  74.0  67.0  78.7   73.6  96.5  78.0  75.9  80.452632
# 3    71.9  75.2  66.0  77.5   72.8  94.0  78.0  75.5  79.742105
# 4    69.9  75.2  68.1  76.3   72.4  93.1  79.0  74.5  80.273684
# ..    ...   ...   ...   ...    ...   ...   ...   ...        ...
# 361  78.7  70.5  79.9  76.3  105.0  81.1  79.0  92.3  89.689474
# 362  79.9  69.3  78.7  76.3  104.0  81.1  78.0  92.3  85.242105
# 363  80.3  69.3  78.7  75.5  103.0  80.1  77.3  90.9  86.184211
# 364  78.3  67.0  77.5  75.2  101.0  80.1  76.9  90.9  85.236842
# 365  77.5  67.0  77.5  75.2  101.0  80.1  75.9  93.8  83.947368
#
# [366 rows x 22 columns]

# %%
out_df = pd.DataFrame({'Inflow':[0], 'Start Storage':[6386.536081], 'Avg Storage':[0], 'Elevation':[0], 'Area':[0], 'ET':[0], 'ET Loss':[0], 'Release':[0], 'Spill':[0], 'End Storage':[0], 'Avg Storage New':[0],'Spill Power':[0]})

# %%
inflow = inflow_df['Mean']*(30*60*24)/(10**6)
ET_mm = et_df['Eva. mm']

# %%
for i in range(366):
    out_df.loc[i,'Inflow'] = inflow[i]
    out_df.loc[i,'Avg Storage'] = out_df.loc[i,'Start Storage']
    out_df.loc[i,'Elevation'], out_df.loc[i,'Area'] = interpolator(out_df.loc[i,'Avg Storage'], res_df)
    out_df.loc[i,'ET'] = ET_mm[i]
    out_df.loc[i,'ET Loss'] = out_df.loc[i,'Area'] * out_df.loc[i, 'ET']/1000
    out_df.loc[i,'Release'] = release(minm_power, out_df.loc[i,'Elevation'], TWL, efficiency, 'MW', 'Daily')
    if (out_df.loc[i,'Start Storage'] + out_df.loc[i,'Inflow'] - out_df.loc[i,'ET Loss']-out_df.loc[i,'Release']) > reservoir_capacity:
        out_df.loc[i,'Spill'] = out_df.loc[i,'Start Storage'] + out_df.loc[i,'Inflow']-out_df.loc[i,'ET Loss'] - out_df.loc[i,'Release'] - reservoir_capacity
    else:
        out_df.loc[i,'Spill'] = 0
    out_df.loc[i,'End Storage'] = out_df.loc[i,'Start Storage'] + out_df.loc[i,'Inflow'] - out_df.loc[i,'ET Loss'] - out_df.loc[i,'Release']-out_df.loc[i,'Spill']
    out_df.loc[i,'Avg Storage New'] = (out_df.loc[i,'Start Storage'] + out_df.loc[i,'End Storage'])/2
    print("_ "*0)
    print(f"The calculation for index {i} is {out_df.loc[i,:]}")
    diff = abs(out_df.loc[i,'Avg Storage']-out_df.loc[i,'Avg Storage New'])/out_df.loc[i,'Avg Storage']*100
    while diff >= 0.1:
        out_df.loc[i,'Inflow'] = inflow[i]
        out_df.loc[i,'Avg Storage'] = out_df.loc[i,'Avg Storage New']
        out_df.loc[i,'Elevation'], out_df.loc[i,'Area'] = interpolator(out_df.loc[i,'Avg Storage'], res_df)
        out_df.loc[i,'ET'] = ET_mm[i]
        out_df.loc[i,'ET Loss'] = out_df.loc[i,'Area'] * out_df.loc[i, 'ET']/1000
        out_df.loc[i,'Release'] = release(minm_power, out_df.loc[i,'Elevation'], TWL, efficiency, 'MW', 'Daily')
        if (out_df.loc[i,'Start Storage'] + out_df.loc[i,'Inflow'] - out_df.loc[i,'ET Loss']-out_df.loc[i,'Release']) > reservoir_capacity:
            out_df.loc[i,'Spill'] = out_df.loc[i,'Start Storage'] + out_df.loc[i,'Inflow']-out_df.loc[i,'ET Loss'] - out_df.loc[i,'Release'] - reservoir_capacity
        else:
            out_df.loc[i,'Spill'] = 0
        out_df.loc[i,'End Storage'] = out_df.loc[i,'Start Storage'] + out_df.loc[i,'Inflow'] - out_df.loc[i,'ET Loss'] - out_df.loc[i,'Release']-out_df.loc[i,'Spill']
        out_df.loc[i,'Avg Storage New'] = (out_df.loc[i,'Start Storage'] + out_df.loc[i,'End Storage'])/2
        diff = abs(out_df.loc[i,'Avg Storage']-out_df.loc[i,'Avg Storage New'])/out_df.loc[i,'Avg Storage']*100
    out_df.loc[i+1,'Start Storage'] = out_df.loc[i,'End Storage']
    out_df.loc[i,'Spill Power']=9.81*out_df.loc[i,'Spill']*(out_df.loc[i,'Elevation']-TWL)*efficiency/(1000)
# Out:
# The calculation for index 0 is Inflow                3.559680
# Start Storage      6386.536081
# Avg Storage        6386.536081
# Elevation           377.000000
# Area                124.532010
# ET                    6.000000
# ET Loss               0.747192
# Release               2.948886
# Spill                 0.000000
# End Storage        6386.399683
# Avg Storage New    6386.467882
# Spill Power           0.000000
# Name: 0, dtype: float64
#
# The calculation for index 1 is Inflow                3.520573
# Start Storage      6386.399683
# Avg Storage        6386.399683
# Elevation           376.998708
# Area                124.529671
# ET                    6.100000
# ET Loss               0.759631
# Release               2.948900
# Spill                 0.000000
# End Storage        6386.211725
# Avg Storage New    6386.305704
# Spill Power                NaN
# Name: 1, dtype: float64
#
# The calculation for index 2 is Inflow                3.475554
# Start Storage      6386.211725
# Avg Storage        6386.211725
# Elevation           376.996927
# Area                124.526447
# ET                    6.000000
# ET Loss               0.747159
# Release               2.948918
# Spill                 0.000000
# End Storage        6385.991202
# Avg Storage New    6386.101463
# Spill Power                NaN
# Name: 2, dtype: float64
#
# The calculation for index 3 is Inflow                3.444859
# Start Storage      6385.991202
# Avg Storage        6385.991202
# Elevation           376.994838
# Area                124.522665
# ET                    6.000000
# ET Loss               0.747136
# Release               2.948940
# Spill                 0.000000
# End Storage        6385.739984
# Avg Storage New    6385.865593
# Spill Power                NaN
# Name: 3, dtype: float64
#
# The calculation for index 4 is Inflow                3.467823
# Start Storage      6385.739984
# Avg Storage        6385.739984
# Elevation           376.992458
# Area                124.518356
# ET                    5.000000
# ET Loss               0.622592
# Release               2.948965
# Spill                 0.000000
# End Storage        6385.636250
# Avg Storage New    6385.688117
# Spill Power                NaN
# Name: 4, dtype: float64
#
# The calculation for index 5 is Inflow                3.420985
# Start Storage      6385.636250
# Avg Storage        6385.636250
# Elevation           376.991476
# Area                124.516577
# ET                    5.000000
# ET Loss               0.622583
# Release               2.948976
# Spill                 0.000000
# End Storage        6385.485677
# Avg Storage New    6385.560964
# Spill Power                NaN
# Name: 5, dtype: float64
#
# The calculation for index 6 is Inflow                3.453726
# Start Storage      6385.485677
# Avg Storage        6385.485677
# Elevation           376.990049
# Area                124.513994
# ET                    5.000000
# ET Loss               0.622570
# Release               2.948991
# Spill                 0.000000
# End Storage        6385.367842
# Avg Storage New    6385.426760
# Spill Power                NaN
# Name: 6, dtype: float64
#
# The calculation for index 7 is Inflow                4.325912
# Start Storage      6385.367842
# Avg Storage        6385.367842
# Elevation           376.988933
# Area                124.511973
# ET                    5.000000
# ET Loss               0.622560
# Release               2.949003
# Spill                 0.000000
# End Storage        6386.122192
# Avg Storage New    6385.745017
# Spill Power                NaN
# Name: 7, dtype: float64
#
# The calculation for index 8 is Inflow                4.079217
# Start Storage      6386.122192
# Avg Storage        6386.122192
# Elevation           376.996079
# Area                124.524911
# ET                    5.000000
# ET Loss               0.622625
# Release               2.948927
# Spill                 0.000000
# End Storage        6386.629857
# Avg Storage New    6386.376024
# Spill Power                NaN
# Name: 8, dtype: float64
#
# The calculation for index 9 is Inflow                3.587192
# Start Storage      6386.629857
# Avg Storage        6386.629857
# Elevation           377.003057
# Area                124.539068
# ET                    5.000000
# ET Loss               0.622695
# Release               2.948854
# Spill                 0.000000
# End Storage        6386.645499
# Avg Storage New    6386.637678
# Spill Power                NaN
# Name: 9, dtype: float64
#
# The calculation for index 10 is Inflow                3.480328
# Start Storage      6386.645499
# Avg Storage        6386.645499
# Elevation           377.003567
# Area                124.540245
# ET                    5.000000
# ET Loss               0.622701
# Release               2.948848
# Spill                 0.000000
# End Storage        6386.554278
# Avg Storage New    6386.599889
# Spill Power                NaN
# Name: 10, dtype: float64
#
# The calculation for index 11 is Inflow                3.512615
# Start Storage      6386.554278
# Avg Storage        6386.554278
# Elevation           377.000593
# Area                124.533380
# ET                    5.000000
# ET Loss               0.622667
# Release               2.948880
# Spill                 0.000000
# End Storage        6386.495346
# Avg Storage New    6386.524812
# Spill Power                NaN
# Name: 11, dtype: float64
#
# The calculation for index 12 is Inflow                3.417802
# Start Storage      6386.495346
# Avg Storage        6386.495346
# Elevation           376.999614
# Area                124.531311
# ET                    5.000000
# ET Loss               0.622657
# Release               2.948890
# Spill                 0.000000
# End Storage        6386.341602
# Avg Storage New    6386.418474
# Spill Power                NaN
# Name: 12, dtype: float64
#
# The calculation for index 13 is Inflow                3.382560
# Start Storage      6386.341602
# Avg Storage        6386.341602
# Elevation           376.998158
# Area                124.528674
# ET                    5.000000
# ET Loss               0.622643
# Release               2.948905
# Spill                 0.000000
# End Storage        6386.152613
# Avg Storage New    6386.247107
# Spill Power                NaN
# Name: 13, dtype: float64
#
# The calculation for index 14 is Inflow                3.375739
# Start Storage      6386.152613
# Avg Storage        6386.152613
# Elevation           376.996367
# Area                124.525433
# ET                    5.000000
# ET Loss               0.622627
# Release               2.948924
# Spill                 0.000000
# End Storage        6385.956800
# Avg Storage New    6386.054707
# Spill Power                NaN
# Name: 14, dtype: float64
#
# The calculation for index 15 is Inflow                3.548539
# Start Storage      6385.956800
# Avg Storage        6385.956800
# Elevation           376.994512
# Area                124.522075
# ET                    5.000000
# ET Loss               0.622610
# Release               2.948944
# Spill                 0.000000
# End Storage        6385.933785
# Avg Storage New    6385.945293
# Spill Power                NaN
# Name: 15, dtype: float64
#
# The calculation for index 16 is Inflow                3.497608
# Start Storage      6385.933785
# Avg Storage        6385.933785
# Elevation           376.994294
# Area                124.521680
# ET                    5.000000
# ET Loss               0.622608
# Release               2.948946
# Spill                 0.000000
# End Storage        6385.859839
# Avg Storage New    6385.896812
# Spill Power                NaN
# Name: 16, dtype: float64
#
# The calculation for index 17 is Inflow                3.320261
# Start Storage      6385.859839
# Avg Storage        6385.859839
# Elevation           376.993594
# Area                124.520412
# ET                    5.200000
# ET Loss               0.647506
# Release               2.948953
# Spill                 0.000000
# End Storage        6385.583641
# Avg Storage New    6385.721740
# Spill Power                NaN
# Name: 17, dtype: float64
#
# The calculation for index 18 is Inflow                3.272286
# Start Storage      6385.583641
# Avg Storage        6385.583641
# Elevation           376.990977
# Area                124.515674
# ET                    5.300000
# ET Loss               0.659933
# Release               2.948981
# Spill                 0.000000
# End Storage        6385.247013
# Avg Storage New    6385.415327
# Spill Power                NaN
# Name: 18, dtype: float64
#
# The calculation for index 19 is Inflow                3.260691
# Start Storage      6385.247013
# Avg Storage        6385.247013
# Elevation           376.987788
# Area                124.509901
# ET                    5.300000
# ET Loss               0.659902
# Release               2.949015
# Spill                 0.000000
# End Storage        6384.898786
# Avg Storage New    6385.072900
# Spill Power                NaN
# Name: 19, dtype: float64
#
# The calculation for index 20 is Inflow                3.307528
# Start Storage      6384.898786
# Avg Storage        6384.898786
# Elevation           376.984490
# Area                124.503928
# ET                    5.300000
# ET Loss               0.659871
# Release               2.949049
# Spill                 0.000000
# End Storage        6384.597395
# Avg Storage New    6384.748090
# Spill Power                NaN
# Name: 20, dtype: float64
#
# The calculation for index 21 is Inflow                3.251823
# Start Storage      6384.597395
# Avg Storage        6384.597395
# Elevation           376.981634
# Area                124.498759
# ET                    5.300000
# ET Loss               0.659843
# Release               2.949079
# Spill                 0.000000
# End Storage        6384.240295
# Avg Storage New    6384.418845
# Spill Power                NaN
# Name: 21, dtype: float64
#
# The calculation for index 22 is Inflow                3.193162
# Start Storage      6384.240295
# Avg Storage        6384.240295
# Elevation           376.978251
# Area                124.492634
# ET                    5.300000
# ET Loss               0.659811
# Release               2.949115
# Spill                 0.000000
# End Storage        6383.824531
# Avg Storage New    6384.032413
# Spill Power                NaN
# Name: 22, dtype: float64
#
# The calculation for index 23 is Inflow                3.174291
# Start Storage      6383.824531
# Avg Storage        6383.824531
# Elevation           376.974313
# Area                124.485503
# ET                    5.300000
# ET Loss               0.659773
# Release               2.949157
# Spill                 0.000000
# End Storage        6383.389892
# Avg Storage New    6383.607211
# Spill Power                NaN
# Name: 23, dtype: float64
#
# The calculation for index 24 is Inflow                3.217263
# Start Storage      6383.389892
# Avg Storage        6383.389892
# Elevation           376.970195
# Area                124.478049
# ET                    5.300000
# ET Loss               0.659734
# Release               2.949200
# Spill                 0.000000
# End Storage        6382.998221
# Avg Storage New    6383.194057
# Spill Power                NaN
# Name: 24, dtype: float64
#
# The calculation for index 25 is Inflow                3.226131
# Start Storage      6382.998221
# Avg Storage        6382.998221
# Elevation           376.966485
# Area                124.471331
# ET                    5.300000
# ET Loss               0.659698
# Release               2.949239
# Spill                 0.000000
# End Storage        6382.615415
# Avg Storage New    6382.806818
# Spill Power                NaN
# Name: 25, dtype: float64
#
# The calculation for index 26 is Inflow                3.216126
# Start Storage      6382.615415
# Avg Storage        6382.615415
# Elevation           376.962859
# Area                124.464765
# ET                    5.300000
# ET Loss               0.659663
# Release               2.949277
# Spill                 0.000000
# End Storage        6382.222601
# Avg Storage New    6382.419008
# Spill Power                NaN
# Name: 26, dtype: float64
#
# The calculation for index 27 is Inflow                3.186341
# Start Storage      6382.222601
# Avg Storage        6382.222601
# Elevation           376.959137
# Area                124.458028
# ET                    5.300000
# ET Loss               0.659628
# Release               2.949316
# Spill                 0.000000
# End Storage        6381.799998
# Avg Storage New    6382.011299
# Spill Power                NaN
# Name: 27, dtype: float64
#
# The calculation for index 28 is Inflow                3.390745
# Start Storage      6381.799998
# Avg Storage        6381.799998
# Elevation           376.955134
# Area                124.450780
# ET                    5.300000
# ET Loss               0.659589
# Release               2.949359
# Spill                 0.000000
# End Storage        6381.581795
# Avg Storage New    6381.690897
# Spill Power                NaN
# Name: 28, dtype: float64
#
# The calculation for index 29 is Inflow                3.233406
# Start Storage      6381.581795
# Avg Storage        6381.581795
# Elevation           376.953067
# Area                124.447038
# ET                    5.300000
# ET Loss               0.659569
# Release               2.949380
# Spill                 0.000000
# End Storage        6381.206252
# Avg Storage New    6381.394024
# Spill Power                NaN
# Name: 29, dtype: float64
#
# The calculation for index 30 is Inflow                3.287747
# Start Storage      6381.206252
# Avg Storage        6381.206252
# Elevation           376.949509
# Area                124.440596
# ET                    5.300000
# ET Loss               0.659535
# Release               2.949418
# Spill                 0.000000
# End Storage        6380.885046
# Avg Storage New    6381.045649
# Spill Power                NaN
# Name: 30, dtype: float64
#
# The calculation for index 31 is Inflow                3.233634
# Start Storage      6380.885046
# Avg Storage        6380.885046
# Elevation           376.946466
# Area                124.435087
# ET                    5.300000
# ET Loss               0.659506
# Release               2.949450
# Spill                 0.000000
# End Storage        6380.509724
# Avg Storage New    6380.697385
# Spill Power                NaN
# Name: 31, dtype: float64
#
# The calculation for index 32 is Inflow                3.174063
# Start Storage      6380.509724
# Avg Storage        6380.509724
# Elevation           376.942911
# Area                124.428650
# ET                    5.300000
# ET Loss               0.659472
# Release               2.949487
# Spill                 0.000000
# End Storage        6380.074828
# Avg Storage New    6380.292276
# Spill Power                NaN
# Name: 32, dtype: float64
#
# The calculation for index 33 is Inflow                3.106989
# Start Storage      6380.074828
# Avg Storage        6380.074828
# Elevation           376.938791
# Area                124.421191
# ET                    5.300000
# ET Loss               0.659432
# Release               2.949531
# Spill                 0.000000
# End Storage        6379.572855
# Avg Storage New    6379.823841
# Spill Power                NaN
# Name: 33, dtype: float64
#
# The calculation for index 34 is Inflow                3.092893
# Start Storage      6379.572855
# Avg Storage        6379.572855
# Elevation           376.934036
# Area                124.412582
# ET                    5.300000
# ET Loss               0.659387
# Release               2.949581
# Spill                 0.000000
# End Storage        6379.056780
# Avg Storage New    6379.314817
# Spill Power                NaN
# Name: 34, dtype: float64
#
# The calculation for index 35 is Inflow                3.112674
# Start Storage      6379.056780
# Avg Storage        6379.056780
# Elevation           376.929147
# Area                124.403730
# ET                    5.300000
# ET Loss               0.659340
# Release               2.949632
# Spill                 0.000000
# End Storage        6378.560481
# Avg Storage New    6378.808630
# Spill Power                NaN
# Name: 35, dtype: float64
#
# The calculation for index 36 is Inflow                3.069928
# Start Storage      6378.560481
# Avg Storage        6378.560481
# Elevation           376.924445
# Area                124.395218
# ET                    5.300000
# ET Loss               0.659295
# Release               2.949682
# Spill                 0.000000
# End Storage        6378.021433
# Avg Storage New    6378.290957
# Spill Power                NaN
# Name: 36, dtype: float64
#
# The calculation for index 37 is Inflow                3.087891
# Start Storage      6378.021433
# Avg Storage        6378.021433
# Elevation           376.919339
# Area                124.385973
# ET                    5.300000
# ET Loss               0.659246
# Release               2.949736
# Spill                 0.000000
# End Storage        6377.500342
# Avg Storage New    6377.760888
# Spill Power                NaN
# Name: 37, dtype: float64
#
# The calculation for index 38 is Inflow                3.095166
# Start Storage      6377.500342
# Avg Storage        6377.500342
# Elevation           376.914402
# Area                124.377035
# ET                    5.300000
# ET Loss               0.659198
# Release               2.949788
# Spill                 0.000000
# End Storage        6376.986523
# Avg Storage New    6377.243432
# Spill Power                NaN
# Name: 38, dtype: float64
#
# The calculation for index 39 is Inflow                3.332312
# Start Storage      6376.986523
# Avg Storage        6376.986523
# Elevation           376.909535
# Area                124.368223
# ET                    5.300000
# ET Loss               0.659152
# Release               2.949839
# Spill                 0.000000
# End Storage        6376.709844
# Avg Storage New    6376.848183
# Spill Power                NaN
# Name: 39, dtype: float64
#
# The calculation for index 40 is Inflow                3.131773
# Start Storage      6376.709844
# Avg Storage        6376.709844
# Elevation           376.906914
# Area                124.363477
# ET                    5.300000
# ET Loss               0.659126
# Release               2.949867
# Spill                 0.000000
# End Storage        6376.232623
# Avg Storage New    6376.471233
# Spill Power                NaN
# Name: 40, dtype: float64
#
# The calculation for index 41 is Inflow                3.106762
# Start Storage      6376.232623
# Avg Storage        6376.232623
# Elevation           376.902393
# Area                124.355292
# ET                    5.600000
# ET Loss               0.696390
# Release               2.949914
# Spill                 0.000000
# End Storage        6375.693081
# Avg Storage New    6375.962852
# Spill Power                NaN
# Name: 41, dtype: float64
#
# The calculation for index 42 is Inflow                3.099032
# Start Storage      6375.693081
# Avg Storage        6375.693081
# Elevation           376.897282
# Area                124.346038
# ET                    5.600000
# ET Loss               0.696338
# Release               2.949968
# Spill                 0.000000
# End Storage        6375.145807
# Avg Storage New    6375.419444
# Spill Power                NaN
# Name: 42, dtype: float64
#
# The calculation for index 43 is Inflow                3.070838
# Start Storage      6375.145807
# Avg Storage        6375.145807
# Elevation           376.892097
# Area                124.336652
# ET                    5.600000
# ET Loss               0.696285
# Release               2.950023
# Spill                 0.000000
# End Storage        6374.570337
# Avg Storage New    6374.858072
# Spill Power                NaN
# Name: 43, dtype: float64
#
# The calculation for index 44 is Inflow                3.233861
# Start Storage      6374.570337
# Avg Storage        6374.570337
# Elevation           376.886646
# Area                124.326782
# ET                    5.600000
# ET Loss               0.696230
# Release               2.950080
# Spill                 0.000000
# End Storage        6374.157887
# Avg Storage New    6374.364112
# Spill Power                NaN
# Name: 44, dtype: float64
#
# The calculation for index 45 is Inflow                3.152918
# Start Storage      6374.157887
# Avg Storage        6374.157887
# Elevation           376.882738
# Area                124.319708
# ET                    5.600000
# ET Loss               0.696190
# Release               2.950121
# Spill                 0.000000
# End Storage        6373.664493
# Avg Storage New    6373.911190
# Spill Power                NaN
# Name: 45, dtype: float64
#
# The calculation for index 46 is Inflow                3.191571
# Start Storage      6373.664493
# Avg Storage        6373.664493
# Elevation           376.878064
# Area                124.311245
# ET                    5.600000
# ET Loss               0.696143
# Release               2.950171
# Spill                 0.000000
# End Storage        6373.209750
# Avg Storage New    6373.437122
# Spill Power                NaN
# Name: 46, dtype: float64
#
# The calculation for index 47 is Inflow                3.151554
# Start Storage      6373.209750
# Avg Storage        6373.209750
# Elevation           376.873757
# Area                124.303446
# ET                    5.600000
# ET Loss               0.696099
# Release               2.950216
# Spill                 0.000000
# End Storage        6372.714989
# Avg Storage New    6372.962369
# Spill Power                NaN
# Name: 47, dtype: float64
#
# The calculation for index 48 is Inflow                3.096531
# Start Storage      6372.714989
# Avg Storage        6372.714989
# Elevation           376.869070
# Area                124.294960
# ET                    5.600000
# ET Loss               0.696052
# Release               2.950266
# Spill                 0.000000
# End Storage        6372.165202
# Avg Storage New    6372.440095
# Spill Power                NaN
# Name: 48, dtype: float64
#
# The calculation for index 49 is Inflow                3.176564
# Start Storage      6372.165202
# Avg Storage        6372.165202
# Elevation           376.863861
# Area                124.285531
# ET                    5.600000
# ET Loss               0.695999
# Release               2.950320
# Spill                 0.000000
# End Storage        6371.695447
# Avg Storage New    6371.930324
# Spill Power                NaN
# Name: 49, dtype: float64
#
# The calculation for index 50 is Inflow                3.222265
# Start Storage      6371.695447
# Avg Storage        6371.695447
# Elevation           376.859411
# Area                124.277474
# ET                    5.600000
# ET Loss               0.695954
# Release               2.950367
# Spill                 0.000000
# End Storage        6371.271391
# Avg Storage New    6371.483419
# Spill Power                NaN
# Name: 50, dtype: float64
#
# The calculation for index 51 is Inflow                3.617886
# Start Storage      6371.271391
# Avg Storage        6371.271391
# Elevation           376.855394
# Area                124.270201
# ET                    5.600000
# ET Loss               0.695913
# Release               2.950410
# Spill                 0.000000
# End Storage        6371.242954
# Avg Storage New    6371.257172
# Spill Power                NaN
# Name: 51, dtype: float64
#
# The calculation for index 52 is Inflow                3.120177
# Start Storage      6371.242954
# Avg Storage        6371.242954
# Elevation           376.855125
# Area                124.269713
# ET                    5.600000
# ET Loss               0.695910
# Release               2.950413
# Spill                 0.000000
# End Storage        6370.716808
# Avg Storage New    6370.979881
# Spill Power                NaN
# Name: 52, dtype: float64
#
# The calculation for index 53 is Inflow                3.074021
# Start Storage      6370.716808
# Avg Storage        6370.716808
# Elevation           376.850140
# Area                124.260689
# ET                    5.600000
# ET Loss               0.695860
# Release               2.950465
# Spill                 0.000000
# End Storage        6370.144504
# Avg Storage New    6370.430656
# Spill Power                NaN
# Name: 53, dtype: float64
#
# The calculation for index 54 is Inflow                3.099032
# Start Storage      6370.144504
# Avg Storage        6370.144504
# Elevation           376.844719
# Area                124.250873
# ET                    5.600000
# ET Loss               0.695805
# Release               2.950522
# Spill                 0.000000
# End Storage        6369.597208
# Avg Storage New    6369.870856
# Spill Power                NaN
# Name: 54, dtype: float64
#
# The calculation for index 55 is Inflow                3.184977
# Start Storage      6369.597208
# Avg Storage        6369.597208
# Elevation           376.839534
# Area                124.241486
# ET                    5.600000
# ET Loss               0.695752
# Release               2.950577
# Spill                 0.000000
# End Storage        6369.135856
# Avg Storage New    6369.366532
# Spill Power                NaN
# Name: 55, dtype: float64
#
# The calculation for index 56 is Inflow                3.193162
# Start Storage      6369.135856
# Avg Storage        6369.135856
# Elevation           376.835164
# Area                124.233573
# ET                    5.600000
# ET Loss               0.695708
# Release               2.950623
# Spill                 0.000000
# End Storage        6368.682687
# Avg Storage New    6368.909272
# Spill Power                NaN
# Name: 56, dtype: float64
#
# The calculation for index 57 is Inflow                3.287520
# Start Storage      6368.682687
# Avg Storage        6368.682687
# Elevation           376.830871
# Area                124.225801
# ET                    5.600000
# ET Loss               0.695664
# Release               2.950668
# Spill                 0.000000
# End Storage        6368.323874
# Avg Storage New    6368.503281
# Spill Power                NaN
# Name: 57, dtype: float64
#
# The calculation for index 58 is Inflow                3.206349
# Start Storage      6368.323874
# Avg Storage        6368.323874
# Elevation           376.827471
# Area                124.219647
# ET                    5.600000
# ET Loss               0.695630
# Release               2.950704
# Spill                 0.000000
# End Storage        6367.883890
# Avg Storage New    6368.103882
# Spill Power                NaN
# Name: 58, dtype: float64
#
# The calculation for index 59 is Inflow                3.392280
# Start Storage      6367.883890
# Avg Storage        6367.883890
# Elevation           376.823303
# Area                124.212101
# ET                    5.600000
# ET Loss               0.695588
# Release               2.950748
# Spill                 0.000000
# End Storage        6367.629834
# Avg Storage New    6367.756862
# Spill Power                NaN
# Name: 59, dtype: float64
#
# The calculation for index 60 is Inflow                3.147461
# Start Storage      6367.629834
# Avg Storage        6367.629834
# Elevation           376.820897
# Area                124.207743
# ET                    5.600000
# ET Loss               0.695563
# Release               2.950773
# Spill                 0.000000
# End Storage        6367.130958
# Avg Storage New    6367.380396
# Spill Power                NaN
# Name: 60, dtype: float64
#
# The calculation for index 61 is Inflow                4.857726
# Start Storage      6367.130958
# Avg Storage        6367.130958
# Elevation           376.816171
# Area                124.199187
# ET                    5.600000
# ET Loss               0.695515
# Release               2.950823
# Spill                 0.000000
# End Storage        6368.342346
# Avg Storage New    6367.736652
# Spill Power                NaN
# Name: 61, dtype: float64
#
# The calculation for index 62 is Inflow                3.461229
# Start Storage      6368.342346
# Avg Storage        6368.342346
# Elevation           376.827646
# Area                124.219964
# ET                    5.600000
# ET Loss               0.695632
# Release               2.950702
# Spill                 0.000000
# End Storage        6368.157241
# Avg Storage New    6368.249793
# Spill Power                NaN
# Name: 62, dtype: float64
#
# The calculation for index 63 is Inflow                3.242501
# Start Storage      6368.157241
# Avg Storage        6368.157241
# Elevation           376.825893
# Area                124.216789
# ET                    5.600000
# ET Loss               0.695614
# Release               2.950721
# Spill                 0.000000
# End Storage        6367.753407
# Avg Storage New    6367.955324
# Spill Power                NaN
# Name: 63, dtype: float64
#
# The calculation for index 64 is Inflow                3.204531
# Start Storage      6367.753407
# Avg Storage        6367.753407
# Elevation           376.822067
# Area                124.209863
# ET                    5.600000
# ET Loss               0.695575
# Release               2.950761
# Spill                 0.000000
# End Storage        6367.311602
# Avg Storage New    6367.532504
# Spill Power                NaN
# Name: 64, dtype: float64
#
# The calculation for index 65 is Inflow                3.425760
# Start Storage      6367.311602
# Avg Storage        6367.311602
# Elevation           376.817882
# Area                124.202285
# ET                    5.600000
# ET Loss               0.695533
# Release               2.950805
# Spill                 0.000000
# End Storage        6367.091024
# Avg Storage New    6367.201313
# Spill Power                NaN
# Name: 65, dtype: float64
#
# The calculation for index 66 is Inflow                3.428488
# Start Storage      6367.091024
# Avg Storage        6367.091024
# Elevation           376.815792
# Area                124.198502
# ET                    5.600000
# ET Loss               0.695512
# Release               2.950827
# Spill                 0.000000
# End Storage        6366.873173
# Avg Storage New    6366.982098
# Spill Power                NaN
# Name: 66, dtype: float64
#
# The calculation for index 67 is Inflow                3.258872
# Start Storage      6366.873173
# Avg Storage        6366.873173
# Elevation           376.813729
# Area                124.194765
# ET                    5.600000
# ET Loss               0.695491
# Release               2.950849
# Spill                 0.000000
# End Storage        6366.485705
# Avg Storage New    6366.679439
# Spill Power                NaN
# Name: 67, dtype: float64
#
# The calculation for index 68 is Inflow                3.238408
# Start Storage      6366.485705
# Avg Storage        6366.485705
# Elevation           376.810058
# Area                124.188120
# ET                    5.600000
# ET Loss               0.695453
# Release               2.950888
# Spill                 0.000000
# End Storage        6366.077772
# Avg Storage New    6366.281738
# Spill Power                NaN
# Name: 68, dtype: float64
#
# The calculation for index 69 is Inflow                3.210669
# Start Storage      6366.077772
# Avg Storage        6366.077772
# Elevation           376.806194
# Area                124.181123
# ET                    5.600000
# ET Loss               0.695414
# Release               2.950929
# Spill                 0.000000
# End Storage        6365.642099
# Avg Storage New    6365.859935
# Spill Power                NaN
# Name: 69, dtype: float64
#
# The calculation for index 70 is Inflow                3.146552
# Start Storage      6365.642099
# Avg Storage        6365.642099
# Elevation           376.802066
# Area                124.173651
# ET                    5.600000
# ET Loss               0.695372
# Release               2.950972
# Spill                 0.000000
# End Storage        6365.142306
# Avg Storage New    6365.392202
# Spill Power                NaN
# Name: 70, dtype: float64
#
# The calculation for index 71 is Inflow                3.240000
# Start Storage      6365.142306
# Avg Storage        6365.142306
# Elevation           376.797332
# Area                124.165079
# ET                    5.600000
# ET Loss               0.695324
# Release               2.951022
# Spill                 0.000000
# End Storage        6364.735959
# Avg Storage New    6364.939133
# Spill Power                NaN
# Name: 71, dtype: float64
#
# The calculation for index 72 is Inflow                3.270467
# Start Storage      6364.735959
# Avg Storage        6364.735959
# Elevation           376.793482
# Area                124.158109
# ET                    5.600000
# ET Loss               0.695285
# Release               2.951063
# Spill                 0.000000
# End Storage        6364.360079
# Avg Storage New    6364.548019
# Spill Power                NaN
# Name: 72, dtype: float64
#
# The calculation for index 73 is Inflow                3.193162
# Start Storage      6364.360079
# Avg Storage        6364.360079
# Elevation           376.789922
# Area                124.151663
# ET                    5.600000
# ET Loss               0.695249
# Release               2.951100
# Spill                 0.000000
# End Storage        6363.906892
# Avg Storage New    6364.133485
# Spill Power                NaN
# Name: 73, dtype: float64
#
# The calculation for index 74 is Inflow                3.213171
# Start Storage      6363.906892
# Avg Storage        6363.906892
# Elevation           376.785628
# Area                124.143890
# ET                    5.600000
# ET Loss               0.695206
# Release               2.951145
# Spill                 0.000000
# End Storage        6363.473711
# Avg Storage New    6363.690301
# Spill Power                NaN
# Name: 74, dtype: float64
#
# The calculation for index 75 is Inflow                3.217718
# Start Storage      6363.473711
# Avg Storage        6363.473711
# Elevation           376.781525
# Area                124.136460
# ET                    5.600000
# ET Loss               0.695164
# Release               2.951189
# Spill                 0.000000
# End Storage        6363.045076
# Avg Storage New    6363.259393
# Spill Power                NaN
# Name: 75, dtype: float64
#
# The calculation for index 76 is Inflow                3.284337
# Start Storage      6363.045076
# Avg Storage        6363.045076
# Elevation           376.777464
# Area                124.129109
# ET                    5.600000
# ET Loss               0.695123
# Release               2.951232
# Spill                 0.000000
# End Storage        6362.683058
# Avg Storage New    6362.864067
# Spill Power                NaN
# Name: 76, dtype: float64
#
# The calculation for index 77 is Inflow                3.332994
# Start Storage      6362.683058
# Avg Storage        6362.683058
# Elevation           376.774035
# Area                124.122900
# ET                    5.600000
# ET Loss               0.695088
# Release               2.951268
# Spill                 0.000000
# End Storage        6362.369696
# Avg Storage New    6362.526377
# Spill Power                NaN
# Name: 77, dtype: float64
#
# The calculation for index 78 is Inflow                3.304573
# Start Storage      6362.369696
# Avg Storage        6362.369696
# Elevation           376.771066
# Area                124.117525
# ET                    5.600000
# ET Loss               0.695058
# Release               2.951299
# Spill                 0.000000
# End Storage        6362.027911
# Avg Storage New    6362.198804
# Spill Power                NaN
# Name: 78, dtype: float64
#
# The calculation for index 79 is Inflow                3.276606
# Start Storage      6362.027911
# Avg Storage        6362.027911
# Elevation           376.767828
# Area                124.111663
# ET                    5.600000
# ET Loss               0.695025
# Release               2.951333
# Spill                 0.000000
# End Storage        6361.658159
# Avg Storage New    6361.843035
# Spill Power                NaN
# Name: 79, dtype: float64
#
# The calculation for index 80 is Inflow                3.319352
# Start Storage      6361.658159
# Avg Storage        6361.658159
# Elevation           376.764326
# Area                124.105321
# ET                    5.600000
# ET Loss               0.694990
# Release               2.951370
# Spill                 0.000000
# End Storage        6361.331151
# Avg Storage New    6361.494655
# Spill Power                NaN
# Name: 80, dtype: float64
#
# The calculation for index 81 is Inflow                3.386880
# Start Storage      6361.331151
# Avg Storage        6361.331151
# Elevation           376.761228
# Area                124.099713
# ET                    5.600000
# ET Loss               0.694958
# Release               2.951403
# Spill                 0.000000
# End Storage        6361.071670
# Avg Storage New    6361.201410
# Spill Power                NaN
# Name: 81, dtype: float64
#
# The calculation for index 82 is Inflow                3.471688
# Start Storage      6361.071670
# Avg Storage        6361.071670
# Elevation           376.758770
# Area                124.095262
# ET                    5.600000
# ET Loss               0.694933
# Release               2.951429
# Spill                 0.000000
# End Storage        6360.896996
# Avg Storage New    6360.984333
# Spill Power                NaN
# Name: 82, dtype: float64
#
# The calculation for index 83 is Inflow                3.564455
# Start Storage      6360.896996
# Avg Storage        6360.896996
# Elevation           376.757115
# Area                124.092266
# ET                    5.600000
# ET Loss               0.694917
# Release               2.951446
# Spill                 0.000000
# End Storage        6360.815088
# Avg Storage New    6360.856042
# Spill Power                NaN
# Name: 83, dtype: float64
#
# The calculation for index 84 is Inflow                3.473735
# Start Storage      6360.815088
# Avg Storage        6360.815088
# Elevation           376.756339
# Area                124.090861
# ET                    6.100000
# ET Loss               0.756954
# Release               2.951454
# Spill                 0.000000
# End Storage        6360.580414
# Avg Storage New    6360.697751
# Spill Power                NaN
# Name: 84, dtype: float64
#
# The calculation for index 85 is Inflow                3.702695
# Start Storage      6360.580414
# Avg Storage        6360.580414
# Elevation           376.754116
# Area                124.086836
# ET                    6.100000
# ET Loss               0.756930
# Release               2.951478
# Spill                 0.000000
# End Storage        6360.574701
# Avg Storage New    6360.577557
# Spill Power                NaN
# Name: 85, dtype: float64
#
# The calculation for index 86 is Inflow                3.615840
# Start Storage      6360.574701
# Avg Storage        6360.574701
# Elevation           376.754062
# Area                124.086738
# ET                    6.100000
# ET Loss               0.756929
# Release               2.951478
# Spill                 0.000000
# End Storage        6360.482133
# Avg Storage New    6360.528417
# Spill Power                NaN
# Name: 86, dtype: float64
#
# The calculation for index 87 is Inflow                3.552177
# Start Storage      6360.482133
# Avg Storage        6360.482133
# Elevation           376.753185
# Area                124.085151
# ET                    6.100000
# ET Loss               0.756919
# Release               2.951488
# Spill                 0.000000
# End Storage        6360.325903
# Avg Storage New    6360.404018
# Spill Power                NaN
# Name: 87, dtype: float64
#
# The calculation for index 88 is Inflow                3.799781
# Start Storage      6360.325903
# Avg Storage        6360.325903
# Elevation           376.751705
# Area                124.082471
# ET                    6.100000
# ET Loss               0.756903
# Release               2.951503
# Spill                 0.000000
# End Storage        6360.417278
# Avg Storage New    6360.371591
# Spill Power                NaN
# Name: 88, dtype: float64
#
# The calculation for index 89 is Inflow                3.810467
# Start Storage      6360.417278
# Avg Storage        6360.417278
# Elevation           376.752570
# Area                124.084038
# ET                    6.100000
# ET Loss               0.756913
# Release               2.951494
# Spill                 0.000000
# End Storage        6360.519339
# Avg Storage New    6360.468308
# Spill Power                NaN
# Name: 89, dtype: float64
#
# The calculation for index 90 is Inflow                3.929381
# Start Storage      6360.519339
# Avg Storage        6360.519339
# Elevation           376.753537
# Area                124.085789
# ET                    6.100000
# ET Loss               0.756923
# Release               2.951484
# Spill                 0.000000
# End Storage        6360.740312
# Avg Storage New    6360.629825
# Spill Power                NaN
# Name: 90, dtype: float64
#
# The calculation for index 91 is Inflow                3.812514
# Start Storage      6360.740312
# Avg Storage        6360.740312
# Elevation           376.755631
# Area                124.089579
# ET                    6.100000
# ET Loss               0.756946
# Release               2.951462
# Spill                 0.000000
# End Storage        6360.844418
# Avg Storage New    6360.792365
# Spill Power                NaN
# Name: 91, dtype: float64
#
# The calculation for index 92 is Inflow                3.686552
# Start Storage      6360.844418
# Avg Storage        6360.844418
# Elevation           376.756617
# Area                124.091364
# ET                    6.100000
# ET Loss               0.756957
# Release               2.951451
# Spill                 0.000000
# End Storage        6360.822561
# Avg Storage New    6360.833489
# Spill Power                NaN
# Name: 92, dtype: float64
#
# The calculation for index 93 is Inflow                3.604472
# Start Storage      6360.822561
# Avg Storage        6360.822561
# Elevation           376.756410
# Area                124.090990
# ET                    6.100000
# ET Loss               0.756955
# Release               2.951454
# Spill                 0.000000
# End Storage        6360.718623
# Avg Storage New    6360.770592
# Spill Power                NaN
# Name: 93, dtype: float64
#
# The calculation for index 94 is Inflow                3.716109
# Start Storage      6360.718623
# Avg Storage        6360.718623
# Elevation           376.755425
# Area                124.089207
# ET                    6.100000
# ET Loss               0.756944
# Release               2.951464
# Spill                 0.000000
# End Storage        6360.726325
# Avg Storage New    6360.722474
# Spill Power                NaN
# Name: 94, dtype: float64
#
# The calculation for index 95 is Inflow                3.569684
# Start Storage      6360.726325
# Avg Storage        6360.726325
# Elevation           376.755498
# Area                124.089339
# ET                    6.100000
# ET Loss               0.756945
# Release               2.951463
# Spill                 0.000000
# End Storage        6360.587601
# Avg Storage New    6360.656963
# Spill Power                NaN
# Name: 95, dtype: float64
#
# The calculation for index 96 is Inflow                3.495107
# Start Storage      6360.587601
# Avg Storage        6360.587601
# Elevation           376.754184
# Area                124.086960
# ET                    6.100000
# ET Loss               0.756930
# Release               2.951477
# Spill                 0.000000
# End Storage        6360.374301
# Avg Storage New    6360.480951
# Spill Power                NaN
# Name: 96, dtype: float64
#
# The calculation for index 97 is Inflow                3.469187
# Start Storage      6360.374301
# Avg Storage        6360.374301
# Elevation           376.752163
# Area                124.083301
# ET                    6.100000
# ET Loss               0.756908
# Release               2.951498
# Spill                 0.000000
# End Storage        6360.135081
# Avg Storage New    6360.254691
# Spill Power                NaN
# Name: 97, dtype: float64
#
# The calculation for index 98 is Inflow                3.555360
# Start Storage      6360.135081
# Avg Storage        6360.135081
# Elevation           376.749897
# Area                124.079198
# ET                    6.100000
# ET Loss               0.756883
# Release               2.951522
# Spill                 0.000000
# End Storage        6359.982036
# Avg Storage New    6360.058559
# Spill Power                NaN
# Name: 98, dtype: float64
#
# The calculation for index 99 is Inflow                3.639259
# Start Storage      6359.982036
# Avg Storage        6359.982036
# Elevation           376.748447
# Area                124.076573
# ET                    6.100000
# ET Loss               0.756867
# Release               2.951538
# Spill                 0.000000
# End Storage        6359.912890
# Avg Storage New    6359.947463
# Spill Power                NaN
# Name: 99, dtype: float64
#
# The calculation for index 100 is Inflow                3.825928
# Start Storage      6359.912890
# Avg Storage        6359.912890
# Elevation           376.747792
# Area                124.075388
# ET                    6.100000
# ET Loss               0.756860
# Release               2.951545
# Spill                 0.000000
# End Storage        6360.030414
# Avg Storage New    6359.971652
# Spill Power                NaN
# Name: 100, dtype: float64
#
# The calculation for index 101 is Inflow                3.756354
# Start Storage      6360.030414
# Avg Storage        6360.030414
# Elevation           376.748906
# Area                124.077403
# ET                    6.100000
# ET Loss               0.756872
# Release               2.951533
# Spill                 0.000000
# End Storage        6360.078363
# Avg Storage New    6360.054388
# Spill Power                NaN
# Name: 101, dtype: float64
#
# The calculation for index 102 is Inflow                3.817971
# Start Storage      6360.078363
# Avg Storage        6360.078363
# Elevation           376.749360
# Area                124.078226
# ET                    6.100000
# ET Loss               0.756877
# Release               2.951528
# Spill                 0.000000
# End Storage        6360.187928
# Avg Storage New    6360.133145
# Spill Power                NaN
# Name: 102, dtype: float64
#
# The calculation for index 103 is Inflow                3.823427
# Start Storage      6360.187928
# Avg Storage        6360.187928
# Elevation           376.750398
# Area                124.080105
# ET                    6.100000
# ET Loss               0.756889
# Release               2.951517
# Spill                 0.000000
# End Storage        6360.302950
# Avg Storage New    6360.245439
# Spill Power                NaN
# Name: 103, dtype: float64
#
# The calculation for index 104 is Inflow                3.830931
# Start Storage      6360.302950
# Avg Storage        6360.302950
# Elevation           376.751487
# Area                124.082078
# ET                    6.100000
# ET Loss               0.756901
# Release               2.951506
# Spill                 0.000000
# End Storage        6360.425474
# Avg Storage New    6360.364212
# Spill Power                NaN
# Name: 104, dtype: float64
#
# The calculation for index 105 is Inflow                3.948480
# Start Storage      6360.425474
# Avg Storage        6360.425474
# Elevation           376.752648
# Area                124.084179
# ET                    6.100000
# ET Loss               0.756913
# Release               2.951493
# Spill                 0.000000
# End Storage        6360.665547
# Avg Storage New    6360.545511
# Spill Power                NaN
# Name: 105, dtype: float64
#
# The calculation for index 106 is Inflow                4.083764
# Start Storage      6360.665547
# Avg Storage        6360.665547
# Elevation           376.754922
# Area                124.088297
# ET                    6.100000
# ET Loss               0.756939
# Release               2.951469
# Spill                 0.000000
# End Storage        6361.040903
# Avg Storage New    6360.853225
# Spill Power                NaN
# Name: 106, dtype: float64
#
# The calculation for index 107 is Inflow                5.026434
# Start Storage      6361.040903
# Avg Storage        6361.040903
# Elevation           376.758478
# Area                124.094734
# ET                    6.100000
# ET Loss               0.756978
# Release               2.951432
# Spill                 0.000000
# End Storage        6362.358927
# Avg Storage New    6361.699915
# Spill Power                NaN
# Name: 107, dtype: float64
#
# The calculation for index 108 is Inflow                4.560328
# Start Storage      6362.358927
# Avg Storage        6362.358927
# Elevation           376.770964
# Area                124.117340
# ET                    6.200000
# ET Loss               0.769528
# Release               2.951300
# Spill                 0.000000
# End Storage        6363.198428
# Avg Storage New    6362.778678
# Spill Power                NaN
# Name: 108, dtype: float64
#
# The calculation for index 109 is Inflow                4.156067
# Start Storage      6363.198428
# Avg Storage        6363.198428
# Elevation           376.778917
# Area                124.131739
# ET                    6.200000
# ET Loss               0.769617
# Release               2.951216
# Spill                 0.000000
# End Storage        6363.633663
# Avg Storage New    6363.416045
# Spill Power                NaN
# Name: 109, dtype: float64
#
# The calculation for index 110 is Inflow                4.093541
# Start Storage      6363.633663
# Avg Storage        6363.633663
# Elevation           376.783040
# Area                124.139204
# ET                    6.200000
# ET Loss               0.769663
# Release               2.951173
# Spill                 0.000000
# End Storage        6364.006368
# Avg Storage New    6363.820015
# Spill Power                NaN
# Name: 110, dtype: float64
#
# The calculation for index 111 is Inflow                4.115141
# Start Storage      6364.006368
# Avg Storage        6364.006368
# Elevation           376.786571
# Area                124.145596
# ET                    6.200000
# ET Loss               0.769703
# ...
#
# The calculation for index 329 is Inflow                4.515309
# Start Storage      7000.000000
# Avg Storage        7000.000000
# Elevation           397.000000
# Area                170.702897
# ET                    8.200000
# ET Loss               1.399764
# Release               2.752294
# Spill                 0.363252
# End Storage        7000.000000
# Avg Storage New    7000.000000
# Spill Power                NaN
# Name: 329, dtype: float64
#
# The calculation for index 330 is Inflow                4.490072
# Start Storage      7000.000000
# Avg Storage        7000.000000
# Elevation           397.000000
# Area                170.702897
# ET                    8.200000
# ET Loss               1.399764
# Release               2.752294
# Spill                 0.338014
# End Storage        7000.000000
# Avg Storage New    7000.000000
# Spill Power                NaN
# Name: 330, dtype: float64
#
# The calculation for index 331 is Inflow                4.472792
# Start Storage      7000.000000
# Avg Storage        7000.000000
# Elevation           397.000000
# Area                170.702897
# ET                    8.200000
# ET Loss               1.399764
# Release               2.752294
# Spill                 0.320734
# End Storage        7000.000000
# Avg Storage New    7000.000000
# Spill Power                NaN
# Name: 331, dtype: float64
#
# The calculation for index 332 is Inflow                4.380253
# Start Storage      7000.000000
# Avg Storage        7000.000000
# Elevation           397.000000
# Area                170.702897
# ET                    8.200000
# ET Loss               1.399764
# Release               2.752294
# Spill                 0.228195
# End Storage        7000.000000
# Avg Storage New    7000.000000
# Spill Power                NaN
# Name: 332, dtype: float64
#
# The calculation for index 333 is Inflow                4.315225
# Start Storage      7000.000000
# Avg Storage        7000.000000
# Elevation           397.000000
# Area                170.702897
# ET                    8.200000
# ET Loss               1.399764
# Release               2.752294
# Spill                 0.163168
# End Storage        7000.000000
# Avg Storage New    7000.000000
# Spill Power                NaN
# Name: 333, dtype: float64
#
# The calculation for index 334 is Inflow                4.252926
# Start Storage      7000.000000
# Avg Storage        7000.000000
# Elevation           397.000000
# Area                170.702897
# ET                    8.200000
# ET Loss               1.399764
# Release               2.752294
# Spill                 0.100869
# End Storage        7000.000000
# Avg Storage New    7000.000000
# Spill Power                NaN
# Name: 334, dtype: float64
#
# The calculation for index 335 is Inflow                4.283394
# Start Storage      7000.000000
# Avg Storage        7000.000000
# Elevation           397.000000
# Area                170.702897
# ET                    8.200000
# ET Loss               1.399764
# Release               2.752294
# Spill                 0.131336
# End Storage        7000.000000
# Avg Storage New    7000.000000
# Spill Power                NaN
# Name: 335, dtype: float64
#
# The calculation for index 336 is Inflow                4.234737
# Start Storage      7000.000000
# Avg Storage        7000.000000
# Elevation           397.000000
# Area                170.702897
# ET                    8.200000
# ET Loss               1.399764
# Release               2.752294
# Spill                 0.082680
# End Storage        7000.000000
# Avg Storage New    7000.000000
# Spill Power                NaN
# Name: 336, dtype: float64
#
# The calculation for index 337 is Inflow                4.144926
# Start Storage      7000.000000
# Avg Storage        7000.000000
# Elevation           397.000000
# Area                170.702897
# ET                    8.200000
# ET Loss               1.399764
# Release               2.752294
# Spill                 0.000000
# End Storage        6999.992869
# Avg Storage New    6999.996434
# Spill Power                NaN
# Name: 337, dtype: float64
#
# The calculation for index 338 is Inflow                4.114914
# Start Storage      6999.992869
# Avg Storage        6999.992869
# Elevation           396.999768
# Area                170.702360
# ET                    8.200000
# ET Loss               1.399759
# Release               2.752296
# Spill                 0.000000
# End Storage        6999.955728
# Avg Storage New    6999.974298
# Spill Power                NaN
# Name: 338, dtype: float64
#
# The calculation for index 339 is Inflow                4.080126
# Start Storage      6999.955728
# Avg Storage        6999.955728
# Elevation           396.998557
# Area                170.699565
# ET                    8.200000
# ET Loss               1.399736
# Release               2.752307
# Spill                 0.000000
# End Storage        6999.883811
# Avg Storage New    6999.919769
# Spill Power                NaN
# Name: 339, dtype: float64
#
# The calculation for index 340 is Inflow                4.051023
# Start Storage      6999.883811
# Avg Storage        6999.883811
# Elevation           396.996212
# Area                170.694152
# ET                    7.200000
# ET Loss               1.228998
# Release               2.752328
# Spill                 0.000000
# End Storage        6999.953508
# Avg Storage New    6999.918659
# Spill Power                NaN
# Name: 340, dtype: float64
#
# The calculation for index 341 is Inflow                4.041019
# Start Storage      6999.953508
# Avg Storage        6999.953508
# Elevation           396.998484
# Area                170.699398
# ET                    7.200000
# ET Loss               1.229036
# Release               2.752307
# Spill                 0.013183
# End Storage        7000.000000
# Avg Storage New    6999.976754
# Spill Power                NaN
# Name: 341, dtype: float64
#
# The calculation for index 342 is Inflow                4.053297
# Start Storage      7000.000000
# Avg Storage        7000.000000
# Elevation           397.000000
# Area                170.702897
# ET                    7.200000
# ET Loss               1.229061
# Release               2.752294
# Spill                 0.071942
# End Storage        7000.000000
# Avg Storage New    7000.000000
# Spill Power                NaN
# Name: 342, dtype: float64
#
# The calculation for index 343 is Inflow                4.047840
# Start Storage      7000.000000
# Avg Storage        7000.000000
# Elevation           397.000000
# Area                170.702897
# ET                    7.200000
# ET Loss               1.229061
# Release               2.752294
# Spill                 0.066486
# End Storage        7000.000000
# Avg Storage New    7000.000000
# Spill Power                NaN
# Name: 343, dtype: float64
#
# The calculation for index 344 is Inflow                4.859773
# Start Storage      7000.000000
# Avg Storage        7000.000000
# Elevation           397.000000
# Area                170.702897
# ET                    7.200000
# ET Loss               1.229061
# Release               2.752294
# Spill                 0.878418
# End Storage        7000.000000
# Avg Storage New    7000.000000
# Spill Power                NaN
# Name: 344, dtype: float64
#
# The calculation for index 345 is Inflow                4.158114
# Start Storage      7000.000000
# Avg Storage        7000.000000
# Elevation           397.000000
# Area                170.702897
# ET                    7.200000
# ET Loss               1.229061
# Release               2.752294
# Spill                 0.176759
# End Storage        7000.000000
# Avg Storage New    7000.000000
# Spill Power                NaN
# Name: 345, dtype: float64
#
# The calculation for index 346 is Inflow                4.029651
# Start Storage      7000.000000
# Avg Storage        7000.000000
# Elevation           397.000000
# Area                170.702897
# ET                    7.200000
# ET Loss               1.229061
# Release               2.752294
# Spill                 0.048296
# End Storage        7000.000000
# Avg Storage New    7000.000000
# Spill Power                NaN
# Name: 346, dtype: float64
#
# The calculation for index 347 is Inflow                4.046703
# Start Storage      7000.000000
# Avg Storage        7000.000000
# Elevation           397.000000
# Area                170.702897
# ET                    7.200000
# ET Loss               1.229061
# Release               2.752294
# Spill                 0.065349
# End Storage        7000.000000
# Avg Storage New    7000.000000
# Spill Power                NaN
# Name: 347, dtype: float64
#
# The calculation for index 348 is Inflow                4.340463
# Start Storage      7000.000000
# Avg Storage        7000.000000
# Elevation           397.000000
# Area                170.702897
# ET                    7.200000
# ET Loss               1.229061
# Release               2.752294
# Spill                 0.359109
# End Storage        7000.000000
# Avg Storage New    7000.000000
# Spill Power                NaN
# Name: 348, dtype: float64
#
# The calculation for index 349 is Inflow                3.909373
# Start Storage      7000.000000
# Avg Storage        7000.000000
# Elevation           397.000000
# Area                170.702897
# ET                    7.200000
# ET Loss               1.229061
# Release               2.752294
# Spill                 0.000000
# End Storage        6999.928018
# Avg Storage New    6999.964009
# Spill Power                NaN
# Name: 349, dtype: float64
#
# The calculation for index 350 is Inflow                3.845027
# Start Storage      6999.928018
# Avg Storage        6999.928018
# Elevation           396.997653
# Area                170.697479
# ET                    7.200000
# ET Loss               1.229022
# Release               2.752315
# Spill                 0.000000
# End Storage        6999.791709
# Avg Storage New    6999.859863
# Spill Power                NaN
# Name: 350, dtype: float64
#
# The calculation for index 351 is Inflow                3.810240
# Start Storage      6999.791709
# Avg Storage        6999.791709
# Elevation           396.993209
# Area                170.687220
# ET                    7.200000
# ET Loss               1.228948
# Release               2.752356
# Spill                 0.000000
# End Storage        6999.620645
# Avg Storage New    6999.706177
# Spill Power                NaN
# Name: 351, dtype: float64
#
# The calculation for index 352 is Inflow                3.752034
# Start Storage      6999.620645
# Avg Storage        6999.620645
# Elevation           396.987632
# Area                170.674346
# ET                    7.200000
# ET Loss               1.228855
# Release               2.752407
# Spill                 0.000000
# End Storage        6999.391416
# Avg Storage New    6999.506030
# Spill Power                NaN
# Name: 352, dtype: float64
#
# The calculation for index 353 is Inflow                3.742257
# Start Storage      6999.391416
# Avg Storage        6999.391416
# Elevation           396.980159
# Area                170.657093
# ET                    5.800000
# ET Loss               0.989811
# Release               2.752476
# Spill                 0.000000
# End Storage        6999.391386
# Avg Storage New    6999.391401
# Spill Power                NaN
# Name: 353, dtype: float64
#
# The calculation for index 354 is Inflow                3.697920
# Start Storage      6999.391386
# Avg Storage        6999.391386
# Elevation           396.980158
# Area                170.657091
# ET                    5.800000
# ET Loss               0.989811
# Release               2.752476
# Spill                 0.000000
# End Storage        6999.347019
# Avg Storage New    6999.369203
# Spill Power                NaN
# Name: 354, dtype: float64
#
# The calculation for index 355 is Inflow                3.649263
# Start Storage      6999.347019
# Avg Storage        6999.347019
# Elevation           396.978712
# Area                170.653752
# ET                    5.800000
# ET Loss               0.989792
# Release               2.752489
# Spill                 0.000000
# End Storage        6999.254002
# Avg Storage New    6999.300511
# Spill Power                NaN
# Name: 355, dtype: float64
#
# The calculation for index 356 is Inflow                3.634029
# Start Storage      6999.254002
# Avg Storage        6999.254002
# Elevation           396.975679
# Area                170.646751
# ET                    5.800000
# ET Loss               0.989751
# Release               2.752517
# Spill                 0.000000
# End Storage        6999.145764
# Avg Storage New    6999.199883
# Spill Power                NaN
# Name: 356, dtype: float64
#
# The calculation for index 357 is Inflow                3.629255
# Start Storage      6999.145764
# Avg Storage        6999.145764
# Elevation           396.972150
# Area                170.638605
# ET                    5.800000
# ET Loss               0.989704
# Release               2.752549
# Spill                 0.000000
# End Storage        6999.032765
# Avg Storage New    6999.089264
# Spill Power                NaN
# Name: 357, dtype: float64
#
# The calculation for index 358 is Inflow                3.646535
# Start Storage      6999.032765
# Avg Storage        6999.032765
# Elevation           396.968466
# Area                170.630100
# ET                    5.800000
# ET Loss               0.989655
# Release               2.752583
# Spill                 0.000000
# End Storage        6998.937062
# Avg Storage New    6998.984914
# Spill Power                NaN
# Name: 358, dtype: float64
#
# The calculation for index 359 is Inflow                3.635166
# Start Storage      6998.937062
# Avg Storage        6998.937062
# Elevation           396.965346
# Area                170.622898
# ET                    5.800000
# ET Loss               0.989613
# Release               2.752612
# Spill                 0.000000
# End Storage        6998.830004
# Avg Storage New    6998.883533
# Spill Power                NaN
# Name: 359, dtype: float64
#
# The calculation for index 360 is Inflow                3.835933
# Start Storage      6998.830004
# Avg Storage        6998.830004
# Elevation           396.961856
# Area                170.614840
# ET                    5.800000
# ET Loss               0.989566
# Release               2.752644
# Spill                 0.000000
# End Storage        6998.923727
# Avg Storage New    6998.876866
# Spill Power                NaN
# Name: 360, dtype: float64
#
# The calculation for index 361 is Inflow                3.874585
# Start Storage      6998.923727
# Avg Storage        6998.923727
# Elevation           396.964912
# Area                170.621894
# ET                    5.800000
# ET Loss               0.989607
# Release               2.752616
# Spill                 0.000000
# End Storage        6999.056090
# Avg Storage New    6998.989909
# Spill Power                NaN
# Name: 361, dtype: float64
#
# The calculation for index 362 is Inflow                3.682459
# Start Storage      6999.056090
# Avg Storage        6999.056090
# Elevation           396.969227
# Area                170.631856
# ET                    6.000000
# ET Loss               1.023791
# Release               2.752576
# Spill                 0.000000
# End Storage        6998.962182
# Avg Storage New    6999.009136
# Spill Power                NaN
# Name: 362, dtype: float64
#
# The calculation for index 363 is Inflow                3.723158
# Start Storage      6998.962182
# Avg Storage        6998.962182
# Elevation           396.966165
# Area                170.624788
# ET                    6.000000
# ET Loss               1.023749
# Release               2.752604
# Spill                 0.000000
# End Storage        6998.908987
# Avg Storage New    6998.935585
# Spill Power                NaN
# Name: 363, dtype: float64
#
# The calculation for index 364 is Inflow                3.682232
# Start Storage      6998.908987
# Avg Storage        6998.908987
# Elevation           396.964431
# Area                170.620785
# ET                    6.000000
# ET Loss               1.023725
# Release               2.752620
# Spill                 0.000000
# End Storage        6998.814874
# Avg Storage New    6998.861931
# Spill Power                NaN
# Name: 364, dtype: float64
#
# The calculation for index 365 is Inflow                3.626526
# Start Storage      6998.814874
# Avg Storage        6998.814874
# Elevation           396.961363
# Area                170.613701
# ET                    6.000000
# ET Loss               1.023682
# Release               2.752648
# Spill                 0.000000
# End Storage        6998.665070
# Avg Storage New    6998.739972
# Spill Power                NaN
# Name: 365, dtype: float64

# %%
out_df
# Out:
#        Inflow  Start Storage  Avg Storage   Elevation        Area   ET  \
# 0    3.559680    6386.536081  6386.536081  377.000000  124.532010  6.0
# 1    3.520573    6386.399683  6386.399683  376.998708  124.529671  6.1
# 2    3.475554    6386.211725  6386.211725  376.996927  124.526447  6.0
# 3    3.444859    6385.991202  6385.991202  376.994838  124.522665  6.0
# 4    3.467823    6385.739984  6385.739984  376.992458  124.518356  5.0
# ..        ...            ...          ...         ...         ...  ...
# 362  3.682459    6999.056090  6999.056090  396.969227  170.631856  6.0
# 363  3.723158    6998.962182  6998.962182  396.966165  170.624788  6.0
# 364  3.682232    6998.908987  6998.908987  396.964431  170.620785  6.0
# 365  3.626526    6998.814874  6998.814874  396.961363  170.613701  6.0
# 366       NaN    6998.665070          NaN         NaN         NaN  NaN
#
#       ET Loss   Release  Spill  End Storage  Avg Storage New  Spill Power
# 0    0.747192  2.948886    0.0  6386.399683      6386.467882          0.0
# 1    0.759631  2.948900    0.0  6386.211725      6386.305704          0.0
# 2    0.747159  2.948918    0.0  6385.991202      6386.101463          0.0
# 3    0.747136  2.948940    0.0  6385.739984      6385.865593          0.0
# 4    0.622592  2.948965    0.0  6385.636250      6385.688117          0.0
# ..        ...       ...    ...          ...              ...          ...
# 362  1.023791  2.752576    0.0  6998.962182      6999.009136          0.0
# 363  1.023749  2.752604    0.0  6998.908987      6998.935585          0.0
# 364  1.023725  2.752620    0.0  6998.814874      6998.861931          0.0
# 365  1.023682  2.752648    0.0  6998.665070      6998.739972          0.0
# 366       NaN       NaN    NaN          NaN              NaN          NaN
#
# [367 rows x 12 columns]
